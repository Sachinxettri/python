# %%
print("hello world")
# Out:
# hello world

# %%
print("my name is dan")
# Out:
# my name is dan

# %%
print("my name is dan bahadur bohora")#this is name
print("i am from nepal")#country name
print("i am learning pyhton")#python language
# Out:
# my name is dan bahadur bohora
# i am from nepal
# i am learning pyhton

# %%
name="dan bahadur bohora"
age=22
country="napal"
print(name)
# Out:
# dan bahadur bohora

# %%
print(age)
# Out:
# 22

# %%
print(country)
# Out:
# napal

# %%
print("my name is",name)
print("my age is ",age)
# Out:
# my name is dan bahadur bohora
# my age is  22

# %%
height = 25.6
isstudent = True

# %%
print(type(name))  #later text
# Out:
# <class 'str'>

# %%
print(type(age))  #number
# Out:
# <class 'int'>

# %%
print(type(height))  # .
# Out:
# <class 'float'>

# %%
print(type(isstudent)) # true false
# Out:
# <class 'bool'>

# %%
5+10
# Out:
# 15

# %%
4-2
# Out:
# 2

# %%
a=10
b=3

# %%
add=a+b
print(add)
# Out:
# 13

# %%
print("addition is ",a+b)
# Out:
# addition is  13

# %%
print("a power b is:",a**b)
# Out:
# a power b is: 1000

# %%
a = 10
b= 3
print("addition is",a+b)
# Out:
# addition is 13

# %%
print(10*3)
# Out:
# 30

# %%
print(10**3)
# Out:
# 1000

# %%
fname ="dan"
lname ="bahadur bohora"

# %%
fullname= fname+" "+lname
print(fullname)
# Out:
# dan bahadur bohora

# %%
text ="machine learning"#text lai thulo ma lekne
print(text.upper())
# Out:
# MACHINE LEARNING

# %%
print(text.lower())#text lai sano ma lekne
# Out:
# machine learning

# %%
print (len(text))#text cound
# Out:
# 16

# %%
name=input("enter your name:")
print ("hello ",name)
# Out:
# enter your name: dan
# hello  dan

# %%
age= int(input("enter your age:"))
print("your age",age)
# Out:
# enter your age: 22
# your age 22

# %%
print("next year you will be: ",age+1)
# Out:
# next year you will be:  23

# %%
marks=[60,75,80,90,55]

# %%
print(marks)
# Out:
# [60, 75, 80, 90, 55]

# %%
print(marks[0])
# Out:
# 60

# %%
print(marks[1])
# Out:
# 75

# %%
print(marks[2])
# Out:
# 80

# %%
print(marks[3])
# Out:
# 90

# %%
print(marks[4])
# Out:
# 55

# %%
secondyear = [ "dev","dan","sachin"]

# %%
print(secondyear[2])
# Out:
# sachin

# %%
secondyear.append("sita")

# %%
print(secondyear)
# Out:
# ['dev', 'dan', 'sachin', 'sita']

# %%
marks=[60,75,80,90,55]

# %%
print("max",max(marks))
# Out:
# max 90

# %%
print("min",min(marks))
# Out:
# min 55

# %%
print("sum",sum(marks))
# Out:
# sum 360

# %%
marks =70
if marks>= 60:
  print("pass")
else:
    print("fail")
# Out:
# pass

# %%
age = 20
if age >=18:
  print("you can vote")
else:
    print("you can not vote")
# Out:
# you can vote

# %%
marks = 95
if marks>=90:
  print(" Grade A")
elif  marks >=80:
  print(" Grade B")
elif marks >=70:
  print(" Grade C")
elif marks >=60:
  print("Grade D")
else:
  print("fail")
# Out:
#  Grade A
