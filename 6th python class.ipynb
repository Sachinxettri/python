# %%
citizenship = input("are you a nepali citizen:")
age = int(input("Enter your age :"))
votercard = input("Do you have a voter card:")

if citizenship == "no":
  print("you cannot vote because you are not a Nepali citizen.")
elif age < 18:
  print("you cannot vote because you are under 18 years old.")
elif votercard == "no":
  print("you cannot vote because you do not have a voter card.")
else:
  print("you can eligible to vote in Nepal.")
# Out:
# are you a nepali citizen: yes
# Enter your age : 20
# Do you have a voter card: yes
# you can eligible to vote in Nepal.

# %%
citizenship = input("Are you a nepali citizen : ").lower()

if citizenship == "no":
    print("you cannot vote because you are not a Nepali citizen.")
elif citizenship == "yes":
    age = int(input("Enter your age : "))
    if age < 18:
        print("you cannot vote because you are under 18 years old.")
    else:
        votercard = input("Do you have a voter card : ").lower()

        if votercard == "yes":
            print("you can eligible to vote in Nepal.")
        else:
            print("you cannot vote because you do not have a voter card.")

else:
    print("Please only input yes or no")
# Out:
# Are you a nepali citizen :  yes
# Enter your age :  20
# Do you have a voter card :  yes
# you can eligible to vote in Nepal.

# %%
marks = 80
marks =int(input("inter your marks:"))
if marks >=90:
    print( "Grade A")
elif marks >= 80:
    print ("Grade B")
elif marks >=70:
    print ("Grade C")
elif marks >=60:
    print ("Grade D")
else:
    print("fail")
# Out:
# inter your marks: 80
# Grade B
